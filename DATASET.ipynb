# %%
import xarray as xr
import glob

files = glob.glob(r"C:\Users\ayush\Downloads\internship project files\*.nc")

print("Total files:", len(files))

print(files[:5])
# Out:
# Total files: 500
# ['C:\\Users\\ayush\\Downloads\\internship project files\\chimanimani_s2_1000.nc', 'C:\\Users\\ayush\\Downloads\\internship project files\\chimanimani_s2_1001.nc', 'C:\\Users\\ayush\\Downloads\\internship project files\\chimanimani_s2_1002.nc', 'C:\\Users\\ayush\\Downloads\\internship project files\\chimanimani_s2_1003.nc', 'C:\\Users\\ayush\\Downloads\\internship project files\\chimanimani_s2_1004.nc']

# %%
ds = xr.open_dataset(files[0])

print(ds)
# Out:
# <xarray.Dataset> Size: 6MB
# Dimensions:      (time: 15, x: 128, y: 128)
# Coordinates:
#   * x            (x) float64 1kB 4.8e+05 4.8e+05 4.8e+05 ... 4.813e+05 4.813e+05
#   * y            (y) float64 1kB 7.789e+06 7.789e+06 ... 7.788e+06 7.788e+06
#   * time         (time) datetime64[ns] 120B 2018-09-06 2018-10-01 ... 2019-08-27
# Data variables: (12/14)
#     B02          (time, x, y) int16 492kB ...
#     B03          (time, x, y) int16 492kB ...
#     B04          (time, x, y) int16 492kB ...
#     B05          (time, x, y) int16 492kB ...
#     B06          (time, x, y) int16 492kB ...
#     B07          (time, x, y) int16 492kB ...
#     ...           ...
#     B11          (time, x, y) int16 492kB ...
#     B12          (time, x, y) int16 492kB ...
#     SCL          (time, x, y) int16 492kB ...
#     MASK         (time, x, y) uint8 246kB ...
#     DEM          (time, x, y) int16 492kB ...
#     spatial_ref  int64 8B ...
# Attributes:
#     ann_id:
#     ann_bbox:
#     event_date:
#     date_confidence:
#     pre_post_dates:
#     annotated:        False
#     satellite:        s2
#     center_lat:       7788160.0
#     center_lon:       480640.0
#     crs:              EPSG:32736

# %%
ds.head()
# Out:
# <xarray.Dataset> Size: 3kB
# Dimensions:      (time: 5, x: 5, y: 5)
# Coordinates:
#   * x            (x) float64 40B 4.8e+05 4.8e+05 4.8e+05 4.8e+05 4.8e+05
#   * y            (y) float64 40B 7.789e+06 7.789e+06 ... 7.789e+06 7.789e+06
#   * time         (time) datetime64[ns] 40B 2018-09-06 2018-10-01 ... 2018-12-20
# Data variables: (12/14)
#     B02          (time, x, y) int16 250B ...
#     B03          (time, x, y) int16 250B ...
#     B04          (time, x, y) int16 250B ...
#     B05          (time, x, y) int16 250B ...
#     B06          (time, x, y) int16 250B ...
#     B07          (time, x, y) int16 250B ...
#     ...           ...
#     B11          (time, x, y) int16 250B ...
#     B12          (time, x, y) int16 250B ...
#     SCL          (time, x, y) int16 250B ...
#     MASK         (time, x, y) uint8 125B ...
#     DEM          (time, x, y) int16 250B ...
#     spatial_ref  int64 8B ...
# Attributes:
#     ann_id:
#     ann_bbox:
#     event_date:
#     date_confidence:
#     pre_post_dates:
#     annotated:        False
#     satellite:        s2
#     center_lat:       7788160.0
#     center_lon:       480640.0
#     crs:              EPSG:32736

# %%
import xarray as xr
import matplotlib.pyplot as plt
ds = xr.open_dataset(files[0])
var_name = list(ds.data_vars.keys())[0]
data = ds[var_name].values.flatten()
data = data[:100]
plt.figure(figsize=(10,5))
plt.plot(data)
plt.title("Satellite Data Visualization")
plt.xlabel("Pixel Index")
plt.ylabel("Signal Value")
plt.grid(True)
plt.show()
